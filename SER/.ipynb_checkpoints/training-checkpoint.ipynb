# %%
# !rm -rf utils.py
#wget https://raw.githubusercontent.com/sevenfx/fastai_audio/master/notebooks/utils.py

# %%
import os
import glob
import shutil
from pathlib import Path
from IPython.display import Audio
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from utils import read_file, transform_path
# Out:
# e:\python file\python37\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# e:\python file\python37\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-716bb9f1bc16> in <module>
#       5 from IPython.display import Audio
#       6 import librosa
# ----> 7 import librosa.display
#       8 import matplotlib.pyplot as plt
#       9 import numpy as np
#
# e:\python file\python37\lib\site-packages\librosa\display.py in <module>
#      21
#      22 import numpy as np
# ---> 23 from matplotlib.cm import get_cmap
#      24 from matplotlib.axes import Axes
#      25 from matplotlib.ticker import Formatter, ScalarFormatter
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
emotions = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}
observed_emotions = ['neutral', 'happy', 'sad', 'angry']

# %%
if not os.path.exists('audios'):
    os.makedirs('audios')
if not os.path.exists('imgs'):
    os.makedirs('imgs')
for file in glob.glob("ravdess_data\Actor_*\*.wav"):
    audio_name = os.path.basename(file)
    path = os.path.join(os.path.dirname(os.path.abspath(file))[27:], audio_name)
    emotion = emotions[audio_name.split("-")[2]]
    if emotion in observed_emotions:
        shutil.copyfile(path, os.path.join('audios', audio_name))
AUDIO_DIR = Path('audios')
IMG_DIR = Path('imgs')

# %%
fnames = os.listdir(str(AUDIO_DIR))
len(fnames), fnames[:5]

# %%
fn = fnames[94]
print(fn)
Audio(str(AUDIO_DIR/fn))
# Out:
# 03-01-01-01-02-02-23.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x, sr = read_file(fn, AUDIO_DIR)
x.shape, sr, x.dtype
# Out:
# ((61395,), 16000, dtype('float32'))

# %%
def log_mel_spec_tfm(fname, src_path, dst_path):
    x, sample_rate = read_file(fname, src_path)
    
    n_fft = 1024
    hop_length = 256
    n_mels = 40
    fmin = 20
    fmax = sample_rate / 2 
    
    mel_spec_power = librosa.feature.melspectrogram(x, sr=sample_rate, n_fft=n_fft, 
                                                    hop_length=hop_length, 
                                                    n_mels=n_mels, power=2.0, 
                                                    fmin=fmin, fmax=fmax)
    mel_spec_db = librosa.power_to_db(mel_spec_power, ref=np.max)
    dst_fname = dst_path / (fname[:-4] + '.png')
    plt.imsave(dst_fname, mel_spec_db)

# %%
log_mel_spec_tfm(fn, AUDIO_DIR, IMG_DIR)
img = plt.imread(str(IMG_DIR/(fn[:-4] + '.png')))
plt.imshow(img, origin='lower');

# %%
# transform_path(AUDIO_DIR, IMG_DIR, log_mel_spec_tfm, fnames=fnames, delete=True)
for fn in fnames:
    log_mel_spec_tfm(fn, AUDIO_DIR, IMG_DIR)
    img = plt.imread(str(IMG_DIR/(fn[:-4] + '.png')))

# %%
os.listdir(str(IMG_DIR))[:10]
# Out:
# ['03-01-01-01-01-01-01.png',
#  '03-01-01-01-01-01-02.png',
#  '03-01-01-01-01-01-03.png',
#  '03-01-01-01-01-01-04.png',
#  '03-01-01-01-01-01-05.png',
#  '03-01-01-01-01-01-06.png',
#  '03-01-01-01-01-01-07.png',
#  '03-01-01-01-01-01-08.png',
#  '03-01-01-01-01-01-09.png',
#  '03-01-01-01-01-01-10.png']

# %%
import fastai
from fastai.vision import *
fastai.__version__
# Out:
# '1.0.60'

# %%
digit_pattern = r'(\d+)-\d+-\d+-\d+-\d+\.png$'

# %%
data = (ImageList.from_folder(IMG_DIR)
        .split_by_rand_pct(.2)
        .label_from_re(digit_pattern)
        .transform(size=(128,64))
        .databunch())
data.c, data.classes
# Out:
# (4, ['01', '03', '04', '05'])

# %%
xs, ys = data.one_batch()
xs.shape, ys.shape
# Out:
# (torch.Size([64, 3, 128, 64]), torch.Size([64]))

# %%
xs.min(), xs.max(), xs.mean(), xs.std()
# Out:
# (tensor(0.0039), tensor(0.9891), tensor(0.3191), tensor(0.1941))

# %%
data.show_batch(4, figsize=(5,9), hide_axis=False)

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit_one_cycle(4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-42d771f7221c> in <module>
# ----> 1 learn = cnn_learner(data, models.resnet18, metrics=accuracy)
#       2 learn.fit_one_cycle(4)
#
# ~\Anaconda3\envs\sars2\lib\site-packages\fastai\vision\learner.py in cnn_learner(data, base_arch, cut, pretrained, lin_ftrs, ps, custom_head, split_on, bn_final, init, concat_pool, **kwargs)
#     100     learn.split(split_on or meta['split'])
#     101     if pretrained: learn.freeze()
# --> 102     if init: apply_init(model[1], init)
#     103     return learn
#     104
#
# ~\Anaconda3\envs\sars2\lib\site-packages\fastai\torch_core.py in apply_init(m, init_func)
#     255 def apply_init(m, init_func:LayerFunc):
#     256     "Initialize all non-batchnorm layers of `m` with `init_func`."
# --> 257     apply_leaf(m, partial(cond_init, init_func=init_func))
#     258
#     259 def in_channels(m:nn.Module) -> List[int]:
#
# ~\Anaconda3\envs\sars2\lib\site-packages\fastai\torch_core.py in apply_leaf(m, f)
#     251     c = children(m)
#     252     if isinstance(m, nn.Module): f(m)
# --> 253     for l in c: apply_leaf(l,f)
#     254
#     255 def apply_init(m, init_func:LayerFunc):
#
# ~\Anaconda3\envs\sars2\lib\site-packages\fastai\torch_core.py in apply_leaf(m, f)
#     250     "Apply `f` to children of `m`."
#     251     c = children(m)
# --> 252     if isinstance(m, nn.Module): f(m)
#     253     for l in c: apply_leaf(l,f)
#     254
#
# ~\Anaconda3\envs\sars2\lib\site-packages\fastai\torch_core.py in cond_init(m, init_func)
#     245 def cond_init(m:nn.Module, init_func:LayerFunc):
#     246     "Initialize the non-batchnorm layers of `m` with `init_func`."
# --> 247     if (not isinstance(m, bn_types)) and requires_grad(m): init_default(m, init_func)
#     248
#     249 def apply_leaf(m:nn.Module, f:LayerFunc):
#
# ~\Anaconda3\envs\sars2\lib\site-packages\fastai\torch_core.py in init_default(m, func)
#     239     "Initialize `m` weights with `func` and set `bias` to 0."
#     240     if func:
# --> 241         if hasattr(m, 'weight'): func(m.weight)
#     242         if hasattr(m, 'bias') and hasattr(m.bias, 'data'): m.bias.data.fill_(0.)
#     243     return m
#
# ~\Anaconda3\envs\sars2\lib\site-packages\torch\nn\init.py in kaiming_normal_(tensor, a, mode, nonlinearity)
#     351     std = gain / math.sqrt(fan)
#     352     with torch.no_grad():
# --> 353         return tensor.normal_(0, std)
#     354
#     355
#
# RuntimeError: CUDA error: no kernel image is available for execution on the device

# %%
learn.unfreeze()
learn.fit_one_cycle(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-385be80ea002> in <module>
# ----> 1 learn.unfreeze()
#       2 learn.fit_one_cycle(4)
#
# NameError: name 'learn' is not defined

# %%
learn.save('resnet-18-ser')

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-aa7f7b70a42b> in <module>
# ----> 1 interp = ClassificationInterpretation.from_learner(learn)
#
# NameError: name 'learn' is not defined

# %%
interp.plot_confusion_matrix(figsize=(10, 10), dpi=60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-48470cb9d61f> in <module>
# ----> 1 interp.plot_confusion_matrix(figsize=(10, 10), dpi=60)
#
# NameError: name 'interp' is not defined

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.fit_one_cycle(2,max_lr=slice(1e-4 / 2 , 1e-2 / 2))

# %%
learn.save('resnet-18-ser-finetune')

# %%
interp_ft = ClassificationInterpretation.from_learner(learn)
interp_ft.plot_confusion_matrix(dpi=60, figsize=(10,10))

# %%
interp_ft.plot_top_losses(k=12, heatmap=False)
